# %%
# !python -m pip uninstall -y ragas langchain-community
# !python -m pip install --no-cache-dir ragas==0.4.3 "langchain-community==0.4.1"
# Out:
# Found existing installation: ragas 0.4.3
# Uninstalling ragas-0.4.3:
#   Successfully uninstalled ragas-0.4.3
# Found existing installation: langchain-community 0.4.2
# Uninstalling langchain-community-0.4.2:
#   Successfully uninstalled langchain-community-0.4.2
# Collecting ragas==0.4.3
#   Downloading ragas-0.4.3-py3-none-any.whl.metadata (23 kB)
# Collecting langchain-community==0.4.1
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.21.0 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (2.4.6)
# Requirement already satisfied: datasets>=4.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (5.0.1)
# Requirement already satisfied: tiktoken in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (0.13.0)
# Requirement already satisfied: pydantic>=2.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (2.13.4)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.5.1)
# Requirement already satisfied: appdirs in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.4.4)
# Requirement already satisfied: diskcache>=5.6.3 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (5.6.3)
# Requirement already satisfied: typer in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (0.25.1)
# Requirement already satisfied: rich in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (14.3.4)
# Requirement already satisfied: openai>=1.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (2.53.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (4.68.2)
# Requirement already satisfied: instructor in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.15.4)
# Requirement already satisfied: pillow>=10.4.0 in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (12.3.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (3.6.1)
# Requirement already satisfied: scikit-network in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (0.33.5)
# Requirement already satisfied: langchain in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.3.15)
# Requirement already satisfied: langchain-core in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.5.4)
# Requirement already satisfied: langchain_openai in /opt/anaconda3/lib/python3.14/site-packages (from ragas==0.4.3) (1.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (1.0.8)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (2.0.51)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (2.34.2)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (3.14.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (2.14.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (0.10.17)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-community==0.4.1) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.4.1) (1.24.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/lib/python3.14/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community==0.4.1) (1.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-core->ragas==0.4.3) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-core->ragas==0.4.3) (0.0.18)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-core->ragas==0.4.3) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-core->ragas==0.4.3) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/lib/python3.14/site-packages (from langchain-core->ragas==0.4.3) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.14/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->ragas==0.4.3) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (4.12.1)
# Requirement already satisfied: distro>=1.7.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/lib/python3.14/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (0.25.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.14/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community==0.4.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas==0.4.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas==0.4.3) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.14/site-packages (from pydantic>=2.0.0->ragas==0.4.3) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/anaconda3/lib/python3.14/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community==0.4.1) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.14/site-packages (from requests<3.0.0,>=2.32.5->langchain-community==0.4.1) (2.7.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1) (1.1.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (3.29.4)
# Requirement already satisfied: pyarrow>=21.0.0 in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (0.4.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (3.0.3)
# Requirement already satisfied: multiprocess<0.70.20 in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (0.70.19)
# Requirement already satisfied: fsspec<=2026.6.0,>=2023.1.0 in /opt/anaconda3/lib/python3.14/site-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets>=4.0.0->ragas==0.4.3) (2026.4.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /opt/anaconda3/lib/python3.14/site-packages (from datasets>=4.0.0->ragas==0.4.3) (1.27.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /opt/anaconda3/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas==0.4.3) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /opt/anaconda3/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets>=4.0.0->ragas==0.4.3) (1.6.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /opt/anaconda3/lib/python3.14/site-packages (from openai>=1.0.0->ragas==0.4.3) (0.14.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /opt/anaconda3/lib/python3.14/site-packages (from instructor->ragas==0.4.3) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /opt/anaconda3/lib/python3.14/site-packages (from instructor->ragas==0.4.3) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.14/site-packages (from jinja2<4.0.0,>=3.1.4->instructor->ragas==0.4.3) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.14/site-packages (from rich->ragas==0.4.3) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.14/site-packages (from rich->ragas==0.4.3) (2.20.0)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.14/site-packages (from typer->ragas==0.4.3) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda3/lib/python3.14/site-packages (from typer->ragas==0.4.3) (0.0.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich->ragas==0.4.3) (0.1.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /opt/anaconda3/lib/python3.14/site-packages (from langchain->ragas==0.4.3) (1.2.11)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /opt/anaconda3/lib/python3.14/site-packages (from langgraph<1.3.0,>=1.2.11->langchain->ragas==0.4.3) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /opt/anaconda3/lib/python3.14/site-packages (from langgraph<1.3.0,>=1.2.11->langchain->ragas==0.4.3) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /opt/anaconda3/lib/python3.14/site-packages (from langgraph<1.3.0,>=1.2.11->langchain->ragas==0.4.3) (0.4.2)
# Requirement already satisfied: ormsgpack>=1.12.0 in /opt/anaconda3/lib/python3.14/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain->ragas==0.4.3) (1.12.2)
# Requirement already satisfied: regex in /opt/anaconda3/lib/python3.14/site-packages (from tiktoken->ragas==0.4.3) (2026.5.9)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.14/site-packages (from pandas->datasets>=4.0.0->ragas==0.4.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->datasets>=4.0.0->ragas==0.4.3) (1.17.0)
# Requirement already satisfied: scipy>=1.7.3 in /opt/anaconda3/lib/python3.14/site-packages (from scikit-network->ragas==0.4.3) (1.18.0)
# Downloading ragas-0.4.3-py3-none-any.whl (466 kB)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.7 MB/s  0:00:00
# Installing collected packages: langchain-community, ragas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ragas]━━━━━ 1/2 [ragas]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-experimental 0.4.2 requires langchain-community<1.0.0,>=0.4.2, but you have langchain-community 0.4.1 which is incompatible.
# Successfully installed langchain-community-0.4.1 ragas-0.4.3

# %%
"""Cell 1 — подготовка датасета для сравнения baseline RAG vs agent.

Переиспользуем 10 single-hop вопросов из golden-датасета прошлой недели
(`rag_eval.ipynb`, Ячейка 2) — вставлены инлайн, без чтения из файла — и
добавляем 5 multi-hop, таких, которые требуют последовательного вызова
двух tool'ов.
"""
import json
import time
from pathlib import Path

import httpx
import pandas as pd
from dotenv import load_dotenv

load_dotenv()

# 10 single-hop вопросов из golden-датасета прошлой недели (rag_eval.ipynb,
# Ячейка 2) — тот же список question/ground_truth, вставленный инлайн
golden = [
    {
        "question": "How does Ridge regression handle multicollinearity?",
        "ground_truth": "Ridge adds an L2 penalty alpha * sum(w_i^2) to the loss, "
                        "which shrinks correlated coefficients toward each other.",
    },
    {
        "question": "What does the alpha parameter control in Ridge?",
        "ground_truth": "Alpha controls regularization strength; larger alpha means "
                        "stronger penalty and smaller coefficients.",
    },
    {
        "question": "What is the difference between Lasso and Ridge?",
        "ground_truth": "Lasso uses L1 penalty which can zero out coefficients (feature "
                        "selection); Ridge uses L2 which shrinks but never zeroes.",
    },
    {
        "question": "What does min_samples_leaf control in a decision tree?",
        "ground_truth": "min_samples_leaf is the minimum number of samples required to be "
                        "at a leaf node; higher values prevent overfitting by limiting depth.",
    },
    {
        "question": "When does a decision tree overfit?",
        "ground_truth": "Trees overfit when grown too deep without min_samples_leaf or "
                        "min_samples_split constraints, memorising training noise.",
    },
    {
        "question": "What is the formula for precision?",
        "ground_truth": "precision = TP / (TP + FP). Fraction of positive predictions that "
                        "are actually positive.",
    },
    {
        "question": "When is recall more important than precision?",
        "ground_truth": "Recall matters most when missing positives is costly: cancer "
                        "screening, fraud detection, anything where false negatives are "
                        "more harmful than false positives.",
    },
    {
        "question": "Что такое L2-регуляризация?",
        "ground_truth": "L2-регуляризация добавляет к функции потерь штраф, "
                        "пропорциональный сумме квадратов коэффициентов модели. "
                        "Используется в Ridge.",
    },
    {
        "question": "Что такое F1-мера?",
        "ground_truth": "F1 — гармоническое среднее precision и recall, "
                        "F1 = 2 * precision * recall / (precision + recall).",
    },
    {
        "question": "Что ты умеешь?",
        "ground_truth": "Отвечаю на вопросы по трём разделам scikit-learn: линейные "
                        "модели, деревья решений, метрики качества.",
    },
]

# 5 multi-hop сценариев: lookup в документации + вычисление в python_repl
MULTI_HOP = [
    {"question": "What is the default alpha in Ridge regression? Compute alpha * 10 with python_repl"},
    {"question": "Find the default max_depth for DecisionTreeClassifier in the docs, then compute 2**10 in python_repl"},
    {"question": "What is L2 penalty formula for Ridge? Calculate it for alpha=0.5 and w=[1,2,3]"},
    {"question": "What is class_weight in LogisticRegression? Compute 1/3 with python_repl as fraction"},
    {"question": "What is the F1 score formula? Compute F1 for precision=0.8 and recall=0.6 with python_repl"},
]
ALL = golden + MULTI_HOP
print(f"Готово: {len(golden)} single-hop + {len(MULTI_HOP)} multi-hop = {len(ALL)} вопросов")
# Out:
# Готово: 10 single-hop + 5 multi-hop = 15 вопросов

# %%
import ragas
print(ragas.__version__)
# Out:
# 0.4.3

# %%
cd ..
# Out:
# /Users/anastasiakazakova/task-api

# %%
"""Cell 2 — baseline: ходим в `/chat` и меряем качество чистого RAG.

На multi-hop вопросах baseline проваливается — это ожидаемо. Цифры идут
в `baseline_metrics.json` для последующего сравнения с agent в Cell 4.
"""
from datasets import Dataset
from langchain_huggingface import HuggingFaceEmbeddings
from ragas import evaluate
from ragas.embeddings import LangchainEmbeddingsWrapper
from ragas.llms import LangchainLLMWrapper
from ragas.metrics import Faithfulness, ResponseRelevancy

from app.llm import get_llm

BASE_URL = "http://localhost:8000"
baseline_results = []

# Дёргаем /chat синхронно на каждом вопросе и копим контекст для RAGAS
for i, item in enumerate(ALL):
    r = httpx.post(f"{BASE_URL}/chat", json={"question": item["question"]}, timeout=60)
    data = r.json()
    baseline_results.append({
        "user_input": item["question"],
        "response": data["answer"],
        "retrieved_contexts": [s["full_context"] for s in data["sources"]],
        "reference": item.get("ground_truth", ""),
    })
    print(f"[{i + 1}/{len(ALL)}] baseline ok")

# Считаем RAGAS-метрики через LLM-judge — обёртки требуются для совместимости
llm = LangchainLLMWrapper(get_llm())
emb = LangchainEmbeddingsWrapper(
    HuggingFaceEmbeddings(
        model_name="intfloat/multilingual-e5-small",
        encode_kwargs={"normalize_embeddings": True},
    )
)
baseline_scores = evaluate(
    dataset=Dataset.from_list(baseline_results),
    metrics=[Faithfulness(llm=llm), ResponseRelevancy(llm=llm, embeddings=emb)],
)
baseline_df = baseline_scores.to_pandas()
Path("notebooks/baseline_metrics.json").write_text(
    json.dumps({
        "faithfulness": float(baseline_df["faithfulness"].mean()),
        "answer_relevancy": float(baseline_df["answer_relevancy"].mean()),
        "n_questions": len(ALL),
    }, indent=2, ensure_ascii=False),
    encoding="utf-8",
)
print(baseline_df[["faithfulness", "answer_relevancy"]].mean())
# Out:
# /var/folders/yf/q78d7_z97bn21nxr33my_fd40000gn/T/ipykernel_65643/2693574736.py:11: DeprecationWarning: Importing Faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import Faithfulness
#   from ragas.metrics import Faithfulness, ResponseRelevancy
# /var/folders/yf/q78d7_z97bn21nxr33my_fd40000gn/T/ipykernel_65643/2693574736.py:11: DeprecationWarning: Importing ResponseRelevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import ResponseRelevancy
#   from ragas.metrics import Faithfulness, ResponseRelevancy
# [1/15] baseline ok
# [2/15] baseline ok
# [3/15] baseline ok
# [4/15] baseline ok
# [5/15] baseline ok
# [6/15] baseline ok
# [7/15] baseline ok
# [8/15] baseline ok
# [9/15] baseline ok
# [10/15] baseline ok
# [11/15] baseline ok
# [12/15] baseline ok
# [13/15] baseline ok
# [14/15] baseline ok
# [15/15] baseline ok
# /var/folders/yf/q78d7_z97bn21nxr33my_fd40000gn/T/ipykernel_65643/2693574736.py:31: DeprecationWarning: LangchainLLMWrapper is deprecated and will be removed in a future version. Use llm_factory instead: from openai import OpenAI; from ragas.llms import llm_factory; llm = llm_factory('gpt-4o-mini', client=OpenAI(api_key='...'))
#   llm = LangchainLLMWrapper(get_llm())
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# /var/folders/yf/q78d7_z97bn21nxr33my_fd40000gn/T/ipykernel_65643/2693574736.py:32: DeprecationWarning: LangchainEmbeddingsWrapper is deprecated and will be removed in a future version. Use the modern embedding providers instead: embedding_factory('openai', model='text-embedding-3-small', client=openai_client) or from ragas.embeddings import OpenAIEmbeddings, GoogleEmbeddings, HuggingFaceEmbeddings
#   emb = LangchainEmbeddingsWrapper(
# Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]

# %%
"""Cell 3 — agent: ходим в `/agent` на тех же 15 вопросах.

В отличие от baseline собираем не только Faithfulness/Relevancy, но и
agent-специфичные метрики — какие tool'ы выбрал и сколько итераций
потребовалось.
"""
agent_results = []
agent_meta = []

for i, item in enumerate(ALL):
    r = httpx.post(
        f"{BASE_URL}/agent",
        json={"question": item["question"], "thread_id": f"eval-{i}"},
        timeout=120,
    )
    data = r.json()
    agent_results.append({
        "user_input": item["question"],
        "response": data["answer"],
        "retrieved_contexts": [s["full_context"] for s in data.get("sources", [])] or [data["answer"]],
        "reference": item.get("ground_truth", ""),
    })
    # Список разных tool'ов в trace — для multi-hop ждём ≥ 2
    tools_used = {step["tool"] for step in data["trace"] if step.get("tool")}
    agent_meta.append({
        "tools_used": sorted(tools_used),
        "n_tools": len(tools_used),
        "iterations": data["iterations"],
        "is_multi_hop": i >= len(golden),
    })
    print(f"[{i + 1}/{len(ALL)}] agent ok · tools={sorted(tools_used)} · iter={data['iterations']}")
    time.sleep(2)  # бережём rate-limit DuckDuckGo и LLM-провайдера

agent_scores = evaluate(
    dataset=Dataset.from_list(agent_results),
    metrics=[Faithfulness(llm=llm), ResponseRelevancy(llm=llm, embeddings=emb)],
)
agent_df = agent_scores.to_pandas()

# tool_choice_accuracy: на multi-hop правильным считаем вызов ≥ 2 tool'ов
mh_meta = [m for m in agent_meta if m["is_multi_hop"]]
tool_choice_accuracy = sum(1 for m in mh_meta if m["n_tools"] >= 2) / max(1, len(mh_meta))

Path("notebooks/agent_metrics.json").write_text(
    json.dumps({
        "faithfulness": float(agent_df["faithfulness"].mean()),
        "answer_relevancy": float(agent_df["answer_relevancy"].mean()),
        "tool_choice_accuracy_multi_hop": tool_choice_accuracy,
        "avg_iterations": sum(m["iterations"] for m in agent_meta) / len(agent_meta),
        "n_questions": len(ALL),
    }, indent=2, ensure_ascii=False),
    encoding="utf-8",
)
print(agent_df[["faithfulness", "answer_relevancy"]].mean())
print(f"tool_choice_accuracy (multi-hop): {tool_choice_accuracy:.2f}")

# %%
"""Cell 4 — сравниваем baseline и agent.

Сводим всё в pandas-таблицу, печатаем в ноутбуке и заодно генерируем
markdown для README. На single-hop ждём близкие числа; на multi-hop —
ощутимый отрыв agent в сторону больших баллов.
"""
baseline_metrics = json.loads(Path("notebooks/baseline_metrics.json").read_text())
agent_metrics = json.loads(Path("notebooks/agent_metrics.json").read_text())

summary = pd.DataFrame([
    {
        "Metric": "Faithfulness (all 15)",
        "Baseline RAG": round(baseline_metrics["faithfulness"], 3),
        "Agent": round(agent_metrics["faithfulness"], 3),
    },
    {
        "Metric": "AnswerRelevancy (all 15)",
        "Baseline RAG": round(baseline_metrics["answer_relevancy"], 3),
        "Agent": round(agent_metrics["answer_relevancy"], 3),
    },
    {
        "Metric": "Tool-choice accuracy (multi-hop)",
        "Baseline RAG": "—",
        "Agent": f"{agent_metrics['tool_choice_accuracy_multi_hop']:.0%}",
    },
    {
        "Metric": "Avg iterations",
        "Baseline RAG": 1,
        "Agent": round(agent_metrics["avg_iterations"], 1),
    },
])

# Pretty-print + markdown для README
print(summary.to_string(index=False))
Path("notebooks/comparison.md").write_text(
    "# Agent vs Baseline RAG\n\n" + summary.to_markdown(index=False) + "\n",
    encoding="utf-8",
)
